# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanogiagu/corso_AML_2023/blob/main/notebooks/es2/AML_2023_HandsOn_2_DnCNN_1D_FILLME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Machine Learning for Physics 2021-2022
# ## Hands-on session 2
#
# Implementation in pytorch of a denoising CNN based on 1D convolutions and [residual learning](https://arxiv.org/abs/1512.03385), trained for the task of isolating the signal from spourious backgrounds in spectra from non-linear fast raman spectroscopy
#
# Based on a modified version of the DnCNN architecture ([K.Shang et al.](https://arxiv.org/abs/1608.03981)), modified for the new task and to work with one dimensional distributions
#
# *Stefano Giagu - v1.0 - 18.2.2022*
#
# *Stefano Giagu & Andrea - v1.1 - 08.3.2022* - A small addition to Residual learning and on how the number of  parameters is computed
#
# Andrea - v2.0 - 14.3.2023 - FillIn version, dilation and concatenation
#
# [SLIDE](https://docs.google.com/presentation/d/1UKUdn0qbDrKynkD8VQ4vVB40mDNi30TSaHMCJOm6EYI/edit?usp=sharing)

# %%
# %pip install sklearn
# %pip install torchvision
# %pip install torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2955 sha256=57734b07595286e01fd469ab882c68ad037b740b7abada358a59542ded4148de
#   Stored in directory: /root/.cache/pip/wheels/f8/e0/3d/9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (0.14.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torchvision) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision) (2.25.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.9/dist-packages (from torchvision) (1.13.1+cu116)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2022.12.7)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.9/dist-packages (1.5.1)

# %%
# needed libaries: numpy, matpoltlib, sklearn, torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from torchsummary import summary

import torch
import torchvision
print(torch.__version__)
print(torchvision.__version__)

import os.path
# Out:
# 1.13.1+cu116
# 0.14.1+cu116

# %%
# define device to use (cpu/gpu)
if torch.cuda.is_available():
  print('# of GPUs available: ', torch.cuda.device_count())
  print('First GPU type: ',torch.cuda.get_device_name(0))
device = ('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Computation device: {device}\n")
# Out:
# # of GPUs available:  1
# First GPU type:  Tesla T4
# Computation device: cuda

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
cd /content/gdrive/MyDrive

# %%
def CreateDir(path):
	# Create a directory if it does not exist
	success = os.path.exists(path)
	if not success:
		os.makedirs(path)
CreateDir("RamanDn")#your folder

# %%
pwd
# Out:
# '/content'

# %%
cd /content/gdrive/MyDrive/RamanDn
# Out:
# /content/gdrive/MyDrive/RamanDn

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/RamanDn'

# %% [markdown]
# # Load dataset
# - it will take a bit of time so please download it before the hands on session

# %%
my_file = "FSRamanSpectra_simulationFumero.zip"
if  os.path.exists(my_file):
    print("fle already donwloaded")
# Out:
# fle already donwloaded

# %%
# download datasets
if not os.path.exists(my_file):
    # !wget http://giagu.web.cern.ch/giagu/CERN/FSRamanSpectra_simulationFumero.zip

# %%
if not os.path.exists("FSRamanSpectra_simulationFumero/"):
    # !unzip FSRamanSpectra_simulationFumero.zip
else:
    print("Folder already exists")
# the zip file contains several examples of clean (ground truth) and  measured spectra 
# (LowNoise, MixedNoise, August17_MixedNoise (a different model of noise with larger statistics), HighNoise). 

# data is availabel as numpy tensors with shape:
# (5000,801): 5000 examples each one with 801 sampling of the fast raman distribution: LowNoise, MixedNoise, HighNoise
# (15000,801): 15000 examples for August17_MixedNoise
# Out:
# Folder already exists

# %%
#read one of the datasets
# Let's use the low noise case
true = np.loadtxt('FSRamanSpectra_simulationFumero/Sclean_LowNoise.txt')
meas = np.loadtxt('FSRamanSpectra_simulationFumero/Snoise_LowNoise.txt')

true = true.transpose()
meas = meas.transpose()

true = true[:,0:-1]# 801 is a silly number when pooling is used, it is easier to discard the fast value
meas = meas[:,0:-1]

print('spectrum shape: ', true.shape)

# normalize all measured spectra amplitudes so that minimum is zero 
for i in range(meas.shape[0]):
   #REPLACEME
   
#plot few examples
plt.figure(figsize=(20,6))

for idx in range(6):
    plt.subplot(1,6,idx+1)
    plt.plot(true[idx], '-r',label="Clean (ground truth)")
    plt.plot(meas[idx], '-b',label="Noisy (input)")
    plt.legend()

plt.tight_layout()
plt.draw()
# Out:
# spectrum shape:  (5000, 800)

# %% [markdown]
# # Split the data in Train / Validation / Test
#
# # Add a channel dimention to the data
#  Conv1D operarion accetps a input shape of [batch, channels, (dimention to apply convoluntion, wavenumber in this case)]
#  We will first add it as last dim and then permute the order.

# %%
# training, validation, test split

testset_frac = 0.2 # test set fraction wrt whole samples
valiset_frac = 0.25 # validation set fraction wrt training+validation

X_train,X_test,Y_train,Y_test = train_test_split(meas,true,test_size=testset_frac, shuffle=True, random_state=1234)
X_train,X_vali,Y_train,Y_vali = train_test_split(X_train,Y_train,test_size=valiset_frac, shuffle=True, random_state=1234)

X_train = np.expand_dims(X_train, -1)
Y_train = np.expand_dims(Y_train, -1)
X_vali = np.expand_dims(X_vali, -1)
Y_vali = np.expand_dims(Y_vali, -1)
X_test = np.expand_dims(X_test, -1)
Y_test = np.expand_dims(Y_test, -1)

print('X_train shape: ',X_train.shape)
print('Y_train shape: ',Y_train.shape)
print('X_vali shape: ',X_vali.shape)
print('Y_vali shape: ',Y_vali.shape)
print('X_test shape: ',X_test.shape)
print('Y_test shape: ',Y_test.shape)
# Out:
# X_train shape:  (3000, 800, 1)
# Y_train shape:  (3000, 800, 1)
# X_vali shape:  (1000, 800, 1)
# Y_vali shape:  (1000, 800, 1)
# X_test shape:  (1000, 800, 1)
# Y_test shape:  (1000, 800, 1)

# %%
# transform numpy vectors to pytorch tensors

X_train_pt = torch.Tensor(X_train)
Y_train_pt = torch.Tensor(Y_train)
X_vali_pt = torch.Tensor(X_vali)
Y_vali_pt = torch.Tensor(Y_vali)
X_test_pt = torch.Tensor(X_test)
Y_test_pt = torch.Tensor(Y_test)

# switch channel dimension position as needed by pytorch (NOTE: in numpy/keras (dim1,dim2,..., channels) in pytorch (channel, dim1, dim2, ...))

X_train_pt = X_train_pt.permute(0,2,1)
Y_train_pt = Y_train_pt.permute(0,2,1)
X_vali_pt = X_vali_pt.permute(0,2,1)
Y_vali_pt = Y_vali_pt.permute(0,2,1)
X_test_pt = X_test_pt.permute(0,2,1)
Y_test_pt = Y_test_pt.permute(0,2,1)

print(X_train_pt.shape)
print(Y_train_pt.shape)
print(X_vali_pt.shape)
print(Y_vali_pt.shape)
print(X_test_pt.shape)
print(Y_test_pt.shape)
# Out:
# torch.Size([3000, 1, 800])
# torch.Size([3000, 1, 800])
# torch.Size([1000, 1, 800])
# torch.Size([1000, 1, 800])
# torch.Size([1000, 1, 800])
# torch.Size([1000, 1, 800])

# %% [markdown]
# # A very informal explanation on why we use residual learning. Read the paper for a better explanation
#
# Trainig a neural network $NN_W(x)$ means finding the best set of weigths $W$ that minimize the Loss function $\sum_{train} L_W(y,\tilde y)$ where $ \tilde y = NN_w(x)$ is the network prediction.
#
# If X is a corrupted  version of y to which is added a source of noise $\epsilon$ (so $X = y + \epsilon$), then the denosing task is to restore the original signal y from the noisy observation X.
#
# In this case the loss can be written as (using a L2 loss as an example):
# $$
# L_W(y,\tilde y) = (y-\tilde y)^2
# $$
#
# Clearly, one solution that minimize the loss is that the output of the network $\tilde y$ match the original sample y.
#
# We can try to solve an easier task teaching the network to remove the noise instead of restore the target. If the noise structure is simpler than the signal (as in most cases) then the network may converge faster and obtain better performance.
#
# In this case we can set the output of the network to be
# $$
# NN_W(X) = X - \tilde y
# $$
#
# Thus the loss can be written as (remenber that $X = y + \epsilon$)
#
# $$
# L_W(y,X-\tilde y) = (y- X - \tilde y)^2 =  (y - y + \epsilon - \tilde y)^2 = ( \epsilon - \tilde y)^2
# $$
#
# In this case a good solution for the task is to reproduce the noisy part of the signal.
#
# In the case of Raman spectra there are two different souces of "corruption": A slow varying baseline and a fast uncorrelated nosise. Still, residual learning will work very well if they are both additive respect to the real signal.

# %%
# Definition of the ANN model: DnCNN 1 Dimensional
# as in the orginal paper: architecture conv1d + 15 x conv1d + BN + relu + conv1d output and residual layer
from torch import nn
import torch.nn.functional as F

# define the network by inerithing from nn.Module class
class DnCNN(nn.Module):
  def __init__(self, num_layers=15):
    super(DnCNN, self).__init__()
    self.num_layers=num_layers
  
    # define layers of the first block
    # 1D convolution (https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html)
    # input 1 channel --> output 64 channels (i.e. convolutional filters)
    self.conv1 = nn.Conv1d(#REPLACEME, kernel_size=10, padding='same', bias=False)
    self.relu1 = nn.ReLU()

    # central blocks: num_layers blocks with conv1d + BN + relu activation
    hlayers = []
    for _ in range(num_layers):
      hlayers.append(nn.Conv1d(#REPLACEME, kernel_size=10, padding='same', bias=False))
      #hlayers.append(nn.BatchNorm1d(64)) # From Andrea: In my experience, it improves convergence for large batches since it allows a larger learning rate. Try to experimetn with it
      hlayers.append(nn.ReLU())

    self.central_block = nn.Sequential(*hlayers) 

    # output block: 64 channels --> 1 output channel (i.e. the original image)
    self.conv3 = nn.Conv1d(#REPLACEME, kernel_size=10, padding='same', bias=False)

  # forward pass: x (input) -> out  
  def forward(self, x):
 

 #REPLACEME

    # residual learning (this way out become the clean spectrum and the network has only to learn the "noise")
    out = #REPLACEME
    return out

# %%
#THIS IS ANOTHER STRATEGY TO INCREASE THE RECEPTIVE FIELD
'''
class UNet1D(nn.Module):
    def __init__(self, in_channels, out_channels, num_filters=64):
        super().__init__()
        
        # Encoder
        self.conv1 = nn.Conv1d(in_channels, num_filters, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(num_filters)
        self.conv2 = nn.Conv1d(num_filters, num_filters*2, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm1d(num_filters*2)
        self.conv3 = nn.Conv1d(num_filters*2, num_filters*4, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(num_filters*4)
        
        # Bottleneck
        self.conv4 = nn.Conv1d(num_filters*4, num_filters*8, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm1d(num_filters*8)
        self.conv5 = nn.Conv1d(num_filters*8, num_filters*8, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm1d(num_filters*8)
        
        # Decoder
        self.upconv6 = nn.ConvTranspose1d(num_filters*8, num_filters*4, kernel_size=2, stride=2)
        self.conv6 = nn.Conv1d(num_filters*8, num_filters*4, kernel_size=3, padding=1)
        self.bn6 = nn.BatchNorm1d(num_filters*4)
        self.upconv7 = nn.ConvTranspose1d(num_filters*4, num_filters*2, kernel_size=2, stride=2)
        self.conv7 = nn.Conv1d(num_filters*4, num_filters*2, kernel_size=3, padding=1)
        self.bn7 = nn.BatchNorm1d(num_filters*2)
        self.upconv8 = nn.ConvTranspose1d(num_filters*2, num_filters, kernel_size=2, stride=2)
        self.conv8 = nn.Conv1d(num_filters*2, num_filters, kernel_size=3, padding=1)
        self.bn8 = nn.BatchNorm1d(num_filters)
        
        # Output
        self.outconv = nn.Conv1d(num_filters, out_channels, kernel_size=1)
        
        # Max pooling
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        
    def forward(self, x):
        # Encoder
        x1 = self.bn1(torch.relu(self.conv1(x)))
        x2 = self.bn2(torch.relu(self.conv2(self.pool(x1))))
        x3 = self.bn3(torch.relu(self.conv3(self.pool(x2))))
        
        # Bottleneck
        x4 = self.bn4(torch.relu(self.conv4(self.pool(x3))))
        x5 = self.bn5(torch.relu(self.conv5(x4)))
        
        # Decoder
        x6 = self.bn6(torch.relu(self.conv6(torch.cat([self.upconv6(x5), x3], dim=1))))
        x7 = self.bn7(torch.relu(self.conv7(torch.cat([self.upconv7(x6), x2], dim=1))))
        x8 = self.bn8(torch.relu(self.conv8(torch.cat([self.upconv8(x7), x1], dim=1))))
        
        # Output
        out = self.outconv(x8)
        
        return x - out
'''
# Out:
# '\nclass UNet1D(nn.Module):\n    def __init__(self, in_channels, out_channels, num_filters=64):\n        super().__init__()\n        \n        # Encoder\n        self.conv1 = nn.Conv1d(in_channels, num_filters, kernel_size=3, padding=1)\n        self.bn1 = nn.BatchNorm1d(num_filters)\n        self.conv2 = nn.Conv1d(num_filters, num_filters*2, kernel_size=3, padding=1)\n        self.bn2 = nn.BatchNorm1d(num_filters*2)\n        self.conv3 = nn.Conv1d(num_filters*2, num_filters*4, kernel_size=3, padding=1)\n        self.bn3 = nn.BatchNorm1d(num_filters*4)\n        \n        # Bottleneck\n        self.conv4 = nn.Conv1d(num_filters*4, num_filters*8, kernel_size=3, padding=1)\n        self.bn4 = nn.BatchNorm1d(num_filters*8)\n        self.conv5 = nn.Conv1d(num_filters*8, num_filters*8, kernel_size=3, padding=1)\n        self.bn5 = nn.BatchNorm1d(num_filters*8)\n        \n        # Decoder\n        self.upconv6 = nn.ConvTranspose1d(num_filters*8, num_filters*4, kernel_size=2, stride=2)\n        self.conv6 = nn.Conv1d(num_filters*8, num_filters*4, kernel_size=3, padding=1)\n        self.bn6 = nn.BatchNorm1d(num_filters*4)\n        self.upconv7 = nn.ConvTranspose1d(num_filters*4, num_filters*2, kernel_size=2, stride=2)\n        self.conv7 = nn.Conv1d(num_filters*4, num_filters*2, kernel_size=3, padding=1)\n        self.bn7 = nn.BatchNorm1d(num_filters*2)\n        self.upconv8 = nn.ConvTranspose1d(num_filters*2, num_filters, kernel_size=2, stride=2)\n        self.conv8 = nn.Conv1d(num_filters*2, num_filters, kernel_size=3, padding=1)\n        self.bn8 = nn.BatchNorm1d(num_filters)\n        \n        # Output\n        self.outconv = nn.Conv1d(num_filters, out_channels, kernel_size=1)\n        \n        # Max pooling\n        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)\n        \n    def forward(self, x):\n        # Encoder\n        x1 = self.bn1(torch.relu(self.conv1(x)))\n        x2 = self.bn2(torch.relu(self.conv2(self.pool(x1))))\n        x3 = self.bn3(torch.relu(self.conv3(self.pool(x2))))\n        \n        # Bottleneck\n        x4 = self.bn4(torch.relu(self.conv4(self.pool(x3))))\n        x5 = self.bn5(torch.relu(self.conv5(x4)))\n        \n        # Decoder\n        x6 = self.bn6(torch.relu(self.conv6(torch.cat([self.upconv6(x5), x3], dim=1))))\n        x7 = self.bn7(torch.relu(self.conv7(torch.cat([self.upconv7(x6), x2], dim=1))))\n        x8 = self.bn8(torch.relu(self.conv8(torch.cat([self.upconv8(x7), x1], dim=1))))\n        \n        # Output\n        out = self.outconv(x8)\n        \n        return x - out\n'

# %%
#THIS IS ANOTHER STRATEGY TO INCREASE THE RECEPTIVE FIELD
'''
class DilatedResidualConvNet(nn.Module):#This is a pseudo waveNET
    def __init__(self, in_channels, out_channels, num_layers=6, num_filters=64, kernel_size=2, dilation_rates=[1, 2, 4, 8, 16,32]):
        super().__init__()
        
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.num_layers = num_layers
        self.num_filters = num_filters
        self.kernel_size = kernel_size
        self.dilation_rates = dilation_rates
        
        # Initial convolution
        self.initial_conv = nn.Conv1d(in_channels, num_filters, kernel_size=1)
        
        # Dilated convolutions
        self.dilated_convs = nn.ModuleList()
        for dilation in dilation_rates:
            dilated_conv = nn.Conv1d(num_filters, num_filters, kernel_size, dilation=dilation, padding="same")
            self.dilated_convs.append(dilated_conv)
        
        # Residual connection
        self.residual_conv = nn.Conv1d(num_filters,in_channels, kernel_size=1,padding=0)
        
        # Final convolution
        self.final_conv = nn.Conv1d(num_filters, out_channels, kernel_size=1)
        
    def forward(self, x):
        # Initial convolution
        x = self.initial_conv(x)
        res = x
        
        # Dilated convolutions
        for i, dilated_conv in enumerate(self.dilated_convs):
            
            #print("dil: ",i)
           # print("x_shape: ",x.shape)
            x = dilated_conv(x)
            #print("x_after dil: ",x.shape)
            
            
            # Residual connection
            
           # print("res_shape: ",res.shape)
            res = self.residual_conv(res)
           # print("res_shape_af_conv: ",res.shape)
           
           # print("x_after cut: ",x.shape)
            res = res - x
            
        # Final convolution
        out = self.final_conv(F.relu(res))
        
        return out
'''

# %% [markdown]
# # Visualize the model architecture and compute the parameters
#
# - The first layer has a kernel size of 10 (it is a windows of length 10 that runs on the spectra). The input is 1D and there is no bias so it has 10 (10x1 + 0) parameters. The layer has 64 of these kernels so the total number of parameters is 64 * 10 = 640
#
# - The others layer have also a kernel size of 10 but its input has now 64 channels (the number of kernels of the previous layer) so each kernel has 64*10 + 0 parameters. The layers have 64 of these kernels so the total number of parameters is 64 * 64 * 10 = 40960.
#
# - How many paramenters has the last layer?

# %%
# instantiate the model
model = DnCNN(num_layers=15)
#model = UNet1D(1,1,32)
#model = DilatedResidualConvNet(1,1)
print(model)

# this is a useful tool to print the structure of the model in a keras-like fashion ... 
from torchsummary import summary
if torch.cuda.is_available():
  summary(model.cuda(), input_size=(1,800))
else:
  summary(model, input_size=(1,800))
# Out:
# DnCNN(
#   (conv1): Conv1d(1, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#   (relu1): ReLU()
#   (central_block): Sequential(
#     (0): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (1): ReLU()
#     (2): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (3): ReLU()
#     (4): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (5): ReLU()
#     (6): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (7): ReLU()
#     (8): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (9): ReLU()
#     (10): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (11): ReLU()
#     (12): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (13): ReLU()
#     (14): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (15): ReLU()
#     (16): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (17): ReLU()
#     (18): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (19): ReLU()
#     (20): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (21): ReLU()
#     (22): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (23): ReLU()
#     (24): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (25): ReLU()
#     (26): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (27): ReLU()
#     (28): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (29): ReLU()
#   )
#   (conv3): Conv1d(64, 1, kernel_size=(10,), stride=(1,), padding=same, bias=False)
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1              [-1, 64, 800]             640
#               ReLU-2              [-1, 64, 800]               0
#             Conv1d-3              [-1, 64, 800]          40,960
#               ReLU-4              [-1, 64, 800]               0
#             Conv1d-5              [-1, 64, 800]          40,960
#               ReLU-6              [-1, 64, 800]               0
#             Conv1d-7              [-1, 64, 800]          40,960
#               ReLU-8              [-1, 64, 800]               0
#             Conv1d-9              [-1, 64, 800]          40,960
#              ReLU-10              [-1, 64, 800]               0
#            Conv1d-11              [-1, 64, 800]          40,960
#              ReLU-12              [-1, 64, 800]               0
#            Conv1d-13              [-1, 64, 800]          40,960
#              ReLU-14              [-1, 64, 800]               0
#            Conv1d-15              [-1, 64, 800]          40,960
#              ReLU-16              [-1, 64, 800]               0
#            Conv1d-17              [-1, 64, 800]          40,960
#              ReLU-18              [-1, 64, 800]               0
#            Conv1d-19              [-1, 64, 800]          40,960
#              ReLU-20              [-1, 64, 800]               0
#            Conv1d-21              [-1, 64, 800]          40,960
#              ReLU-22              [-1, 64, 800]               0
#            Conv1d-23              [-1, 64, 800]          40,960
#              ReLU-24              [-1, 64, 800]               0
#            Conv1d-25              [-1, 64, 800]          40,960
#              ReLU-26              [-1, 64, 800]               0
#            Conv1d-27              [-1, 64, 800]          40,960
#              ReLU-28              [-1, 64, 800]               0
#            Conv1d-29              [-1, 64, 800]          40,960
#              ReLU-30              [-1, 64, 800]               0
#            Conv1d-31              [-1, 64, 800]          40,960
#              ReLU-32              [-1, 64, 800]               0
#            Conv1d-33               [-1, 1, 800]             640
# ================================================================
# Total params: 615,680
# Trainable params: 615,680
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 12.51
# Params size (MB): 2.35
# Estimated Total Size (MB): 14.86
# ----------------------------------------------------------------
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/conv.py:309: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return F.conv1d(input, weight, bias, self.stride,

# %%
# define loss function, monitoring metric and optmizer

#loss MSE
loss_func = nn.MSELoss()

#metric MAE (called L1Loss in pytorch)
metric_func = nn.L1Loss()

# optimizer: Adam
from torch import optim
opt = optim.Adam(model.parameters(), lr=1e-3)

# scheduler for step decay lr schedule
scheduler = optim.lr_scheduler.StepLR(opt, 20, gamma=0.1, last_epoch=-1, verbose=True)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
# move the model into the GPU
model.to('cpu')
print('The model is in the: ', next(model.parameters()).device)
model.to(device)
print('now the model is in the: ', next(model.parameters()).device)
# Out:
# The model is in the:  cpu
# now the model is in the:  cuda:0

# %%
#Checkpoints (to save model parameters during training)
class SaveBestModel:
    def __init__(self, best_valid_loss=float('inf')): #object initialized with best_loss = +infinite
        self.best_valid_loss = best_valid_loss
        
    def __call__(
        self, current_valid_loss, 
        epoch, model, optimizer, criterion, metric,
    ):
        if current_valid_loss < self.best_valid_loss:
            self.best_valid_loss = current_valid_loss
            print(f"\nBest validation loss: {self.best_valid_loss}")
            print(f"\nSaving best model for epoch: {epoch+1}\n")
            # method to save a model (the state_dict: a python dictionary object that 
            # maps each layer to its parameter tensor) and other useful parametrers
            # see: https://pytorch.org/tutorials/beginner/saving_loading_models.html
            torch.save({
                'epoch': epoch+1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': criterion,
                'metric': metric,
                }, 'best_model.pth')

# %%
# training parameters

epochs = 80
batch_size = 128# was 32

# define dataloaders
from torch.utils.data import TensorDataset, DataLoader

dataset_train = TensorDataset(X_train_pt, Y_train_pt) 
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True) 

dataset_vali = TensorDataset(X_vali_pt, Y_vali_pt) 
dataloader_vali = DataLoader(dataset_vali, batch_size=batch_size)

# %%
#training loop

import time

save_best_model = SaveBestModel()

# lists to save loss and metric history
hist_loss = []
hist_metric = []
hist_vloss = []
hist_vmetric = []

#loop over epochs
for epoch in range(epochs):
    t0 = time.time()

    #training step
    model.train()

    train_loss = 0.0
    train_metric = 0.0
    counter = 0
    for xb, yb in dataloader_train: #takes a batch from the train dataloader 
        counter += 1 
        xb=xb.type(torch.float).to(device) #move troch tensors to device (cpu or GPU)
        yb=yb.type(torch.float).to(device)
        
        #REPLACE ME

        train_loss += loss.item() #update total loss
        train_metric += metric.item() #update total metric

        # backpropagation
        #REPLACE ME
        # update weights
        #REPLACE ME
        # set to zero gradients for the next step
       #REPLACE ME
 
    # normalize loss and metric by number of batches
    train_loss = train_loss/counter
    train_metric = train_metric/counter

    # update history
    hist_loss.append(train_loss)
    hist_metric.append(train_metric)


    # evaluation setp (same as trainign but w/o backpropagation)
    model.eval()

    vali_loss = 0.0
    vali_metric = 0.0
    counter = 0
    with torch.no_grad():
      for xb, yb in dataloader_vali:
        counter += 1
        xb=xb.type(torch.float).to(device)
        yb=yb.type(torch.float).to(device)
        pred = model(xb)
        vloss = loss_func(pred, yb)
        vmetric = metric_func(pred, yb)
        vali_loss += vloss.item()
        vali_metric += vmetric.item()
        
    vali_loss = vali_loss/counter
    vali_metric = vali_metric/counter    

    hist_vloss.append(vali_loss)
    hist_vmetric.append(vali_metric)

    #save best model
    save_best_model(vali_loss, epoch, model, opt, loss_func, metric_func)   

    elapsed_time = time.time()-t0
    print("epoch: %d, time(s): %.4f, train loss: %.6f, train metric: %.6f, vali loss: %.6f, vali metric: %.6f" % (epoch+1, elapsed_time, train_loss, train_metric, vali_loss, vali_metric))

    # update learning rate schedule
    scheduler.step()
# Out:
# Best validation loss: 0.21185774356126785
#
# Saving best model for epoch: 1
#
# epoch: 1, time(s): 3.6418, train loss: 0.210167, train metric: 0.321528, vali loss: 0.211858, vali metric: 0.326396
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.005309822561684996
#
# Saving best model for epoch: 2
#
# epoch: 2, time(s): 3.4253, train loss: 0.058533, train metric: 0.144127, vali loss: 0.005310, vali metric: 0.025509
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0033126877387985587
#
# Saving best model for epoch: 3
#
# epoch: 3, time(s): 3.4407, train loss: 0.005818, train metric: 0.038046, vali loss: 0.003313, vali metric: 0.027853
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0022274883813224733
#
# Saving best model for epoch: 4
#
# epoch: 4, time(s): 3.4640, train loss: 0.002594, train metric: 0.020728, vali loss: 0.002227, vali metric: 0.021376
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0014053045597393066
#
# Saving best model for epoch: 5
#
# epoch: 5, time(s): 3.4923, train loss: 0.001723, train metric: 0.018204, vali loss: 0.001405, vali metric: 0.016682
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.001003869816486258
#
# Saving best model for epoch: 6
#
# epoch: 6, time(s): 3.4982, train loss: 0.001237, train metric: 0.015953, vali loss: 0.001004, vali metric: 0.014306
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0008174429385690019
#
# Saving best model for epoch: 7
#
# epoch: 7, time(s): 3.5023, train loss: 0.000995, train metric: 0.014693, vali loss: 0.000817, vali metric: 0.013502
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0007237029785756022
#
# Saving best model for epoch: 8
#
# epoch: 8, time(s): 3.5361, train loss: 0.000835, train metric: 0.013679, vali loss: 0.000724, vali metric: 0.013003
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 9, time(s): 3.5036, train loss: 0.000862, train metric: 0.014931, vali loss: 0.000753, vali metric: 0.014370
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0005649262966471724
#
# Saving best model for epoch: 10
#
# epoch: 10, time(s): 3.5817, train loss: 0.000661, train metric: 0.012751, vali loss: 0.000565, vali metric: 0.011715
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 11, time(s): 3.5300, train loss: 0.000640, train metric: 0.013047, vali loss: 0.000589, vali metric: 0.014090
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.00048235340727842413
#
# Saving best model for epoch: 12
#
# epoch: 12, time(s): 3.5877, train loss: 0.000605, train metric: 0.012793, vali loss: 0.000482, vali metric: 0.011293
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 13, time(s): 3.5663, train loss: 0.000558, train metric: 0.012247, vali loss: 0.000633, vali metric: 0.016389
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 14, time(s): 3.5714, train loss: 0.000596, train metric: 0.013434, vali loss: 0.000546, vali metric: 0.013784
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0004771509047714062
#
# Saving best model for epoch: 15
#
# epoch: 15, time(s): 3.6167, train loss: 0.000671, train metric: 0.014763, vali loss: 0.000477, vali metric: 0.013466
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.00044066471309633926
#
# Saving best model for epoch: 16
#
# epoch: 16, time(s): 3.6244, train loss: 0.000475, train metric: 0.011551, vali loss: 0.000441, vali metric: 0.011522
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0003286299543105997
#
# Saving best model for epoch: 17
#
# epoch: 17, time(s): 3.6056, train loss: 0.000506, train metric: 0.012650, vali loss: 0.000329, vali metric: 0.009499
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0003193641605321318
#
# Saving best model for epoch: 18
#
# epoch: 18, time(s): 3.5885, train loss: 0.000403, train metric: 0.010658, vali loss: 0.000319, vali metric: 0.009809
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 19, time(s): 3.5418, train loss: 0.000476, train metric: 0.012396, vali loss: 0.000455, vali metric: 0.012949
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 20, time(s): 3.6575, train loss: 0.000416, train metric: 0.011723, vali loss: 0.000369, vali metric: 0.012516
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002800097081490094
#
# Saving best model for epoch: 21
#
# epoch: 21, time(s): 3.9110, train loss: 0.000338, train metric: 0.009987, vali loss: 0.000280, vali metric: 0.009978
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002583047553343931
#
# Saving best model for epoch: 22
#
# epoch: 22, time(s): 3.7002, train loss: 0.000301, train metric: 0.008973, vali loss: 0.000258, vali metric: 0.009233
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00024614341782580595
#
# Saving best model for epoch: 23
#
# epoch: 23, time(s): 3.5789, train loss: 0.000291, train metric: 0.008858, vali loss: 0.000246, vali metric: 0.008729
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00023847230477258563
#
# Saving best model for epoch: 24
#
# epoch: 24, time(s): 3.5543, train loss: 0.000284, train metric: 0.008652, vali loss: 0.000238, vali metric: 0.008557
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00023275982312043197
#
# Saving best model for epoch: 25
#
# epoch: 25, time(s): 3.5433, train loss: 0.000280, train metric: 0.008526, vali loss: 0.000233, vali metric: 0.008385
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002295052236149786
#
# Saving best model for epoch: 26
#
# epoch: 26, time(s): 3.5368, train loss: 0.000272, train metric: 0.008422, vali loss: 0.000230, vali metric: 0.008288
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00022892029301146977
#
# Saving best model for epoch: 27
#
# epoch: 27, time(s): 3.5362, train loss: 0.000269, train metric: 0.008309, vali loss: 0.000229, vali metric: 0.008719
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00022184619592735544
#
# Saving best model for epoch: 28
#
# epoch: 28, time(s): 3.5559, train loss: 0.000264, train metric: 0.008386, vali loss: 0.000222, vali metric: 0.008459
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002190053837693995
#
# Saving best model for epoch: 29
#
# epoch: 29, time(s): 3.5375, train loss: 0.000265, train metric: 0.008401, vali loss: 0.000219, vali metric: 0.008220
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 30, time(s): 3.4984, train loss: 0.000256, train metric: 0.008309, vali loss: 0.000220, vali metric: 0.008761
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00020988829783163965
#
# Saving best model for epoch: 31
#
# epoch: 31, time(s): 3.5523, train loss: 0.000250, train metric: 0.008109, vali loss: 0.000210, vali metric: 0.008132
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00020800865422643255
#
# Saving best model for epoch: 32
#
# epoch: 32, time(s): 3.5568, train loss: 0.000242, train metric: 0.007886, vali loss: 0.000208, vali metric: 0.008075
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00020492500516411383
#
# Saving best model for epoch: 33
#
# epoch: 33, time(s): 3.5649, train loss: 0.000240, train metric: 0.007968, vali loss: 0.000205, vali metric: 0.008017
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 34, time(s): 3.5214, train loss: 0.000243, train metric: 0.008269, vali loss: 0.000205, vali metric: 0.008197
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00019468774371489417
#
# Saving best model for epoch: 35
#
# epoch: 35, time(s): 3.5876, train loss: 0.000234, train metric: 0.007722, vali loss: 0.000195, vali metric: 0.007836
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 36, time(s): 3.5327, train loss: 0.000229, train metric: 0.007683, vali loss: 0.000204, vali metric: 0.008544
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 37, time(s): 3.5399, train loss: 0.000240, train metric: 0.008128, vali loss: 0.000196, vali metric: 0.008211
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 38, time(s): 3.5391, train loss: 0.000231, train metric: 0.007989, vali loss: 0.000203, vali metric: 0.008558
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 39, time(s): 3.7082, train loss: 0.000220, train metric: 0.007746, vali loss: 0.000201, vali metric: 0.007921
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00018839910808310378
#
# Saving best model for epoch: 40
#
# epoch: 40, time(s): 3.6512, train loss: 0.000221, train metric: 0.007754, vali loss: 0.000188, vali metric: 0.007596
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.0001816532931115944
#
# Saving best model for epoch: 41
#
# epoch: 41, time(s): 3.5721, train loss: 0.000213, train metric: 0.007444, vali loss: 0.000182, vali metric: 0.007471
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00018044573880615644
#
# Saving best model for epoch: 42
#
# epoch: 42, time(s): 3.5716, train loss: 0.000206, train metric: 0.007285, vali loss: 0.000180, vali metric: 0.007258
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 43, time(s): 3.5371, train loss: 0.000208, train metric: 0.007201, vali loss: 0.000181, vali metric: 0.007453
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00017978779578697868
#
# Saving best model for epoch: 44
#
# epoch: 44, time(s): 3.5743, train loss: 0.000208, train metric: 0.007319, vali loss: 0.000180, vali metric: 0.007315
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00017951020527107175
#
# Saving best model for epoch: 45
#
# epoch: 45, time(s): 3.5767, train loss: 0.000208, train metric: 0.007247, vali loss: 0.000180, vali metric: 0.007346
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00017908779409481212
#
# Saving best model for epoch: 46
#
# epoch: 46, time(s): 3.5656, train loss: 0.000207, train metric: 0.007261, vali loss: 0.000179, vali metric: 0.007331
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 47, time(s): 3.5319, train loss: 0.000206, train metric: 0.007241, vali loss: 0.000179, vali metric: 0.007270
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00017813832710089628
#
# Saving best model for epoch: 48
#
# epoch: 48, time(s): 3.5661, train loss: 0.000204, train metric: 0.007226, vali loss: 0.000178, vali metric: 0.007289
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00017794936138670892
#
# Saving best model for epoch: 49
#
# epoch: 49, time(s): 3.5599, train loss: 0.000207, train metric: 0.007223, vali loss: 0.000178, vali metric: 0.007277
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 50, time(s): 3.5219, train loss: 0.000203, train metric: 0.007206, vali loss: 0.000179, vali metric: 0.007261
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 51, time(s): 3.5292, train loss: 0.000204, train metric: 0.007290, vali loss: 0.000178, vali metric: 0.007212
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 52, time(s): 3.5183, train loss: 0.000204, train metric: 0.007221, vali loss: 0.000178, vali metric: 0.007279
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 53, time(s): 3.5216, train loss: 0.000206, train metric: 0.007181, vali loss: 0.000178, vali metric: 0.007417
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00017681926510704216
#
# Saving best model for epoch: 54
#
# epoch: 54, time(s): 3.5940, train loss: 0.000205, train metric: 0.007275, vali loss: 0.000177, vali metric: 0.007245
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00017623824714974035
#
# Saving best model for epoch: 55
#
# epoch: 55, time(s): 3.5659, train loss: 0.000202, train metric: 0.007189, vali loss: 0.000176, vali metric: 0.007287
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 56, time(s): 3.5212, train loss: 0.000203, train metric: 0.007230, vali loss: 0.000179, vali metric: 0.007317
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 57, time(s): 3.5253, train loss: 0.000203, train metric: 0.007223, vali loss: 0.000177, vali metric: 0.007363
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00017610047871130519
#
# Saving best model for epoch: 58
#
# epoch: 58, time(s): 3.5691, train loss: 0.000203, train metric: 0.007222, vali loss: 0.000176, vali metric: 0.007356
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 59, time(s): 3.5220, train loss: 0.000203, train metric: 0.007235, vali loss: 0.000180, vali metric: 0.007662
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00017516521802463103
#
# Saving best model for epoch: 60
#
# epoch: 60, time(s): 3.5686, train loss: 0.000201, train metric: 0.007238, vali loss: 0.000175, vali metric: 0.007242
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00017496301188657526
#
# Saving best model for epoch: 61
#
# epoch: 61, time(s): 3.5659, train loss: 0.000200, train metric: 0.007132, vali loss: 0.000175, vali metric: 0.007261
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00017491590733698104
#
# Saving best model for epoch: 62
#
# epoch: 62, time(s): 3.5910, train loss: 0.000203, train metric: 0.007182, vali loss: 0.000175, vali metric: 0.007243
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00017489482706878334
#
# Saving best model for epoch: 63
#
# epoch: 63, time(s): 3.5620, train loss: 0.000200, train metric: 0.007170, vali loss: 0.000175, vali metric: 0.007247
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00017477711662650108
#
# Saving best model for epoch: 64
#
# epoch: 64, time(s): 3.5626, train loss: 0.000200, train metric: 0.007144, vali loss: 0.000175, vali metric: 0.007246
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 65, time(s): 3.5322, train loss: 0.000200, train metric: 0.007140, vali loss: 0.000175, vali metric: 0.007240
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00017472101535531692
#
# Saving best model for epoch: 66
#
# epoch: 66, time(s): 3.5692, train loss: 0.000201, train metric: 0.007175, vali loss: 0.000175, vali metric: 0.007239
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 67, time(s): 3.5188, train loss: 0.000200, train metric: 0.007162, vali loss: 0.000175, vali metric: 0.007269
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 68, time(s): 3.5309, train loss: 0.000200, train metric: 0.007139, vali loss: 0.000175, vali metric: 0.007276
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.0001746640627970919
#
# Saving best model for epoch: 69
#
# epoch: 69, time(s): 3.5819, train loss: 0.000200, train metric: 0.007175, vali loss: 0.000175, vali metric: 0.007240
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00017461161587561946
#
# Saving best model for epoch: 70
#
# epoch: 70, time(s): 3.5720, train loss: 0.000200, train metric: 0.007128, vali loss: 0.000175, vali metric: 0.007250
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00017456868772569578
#
# Saving best model for epoch: 71
#
# epoch: 71, time(s): 3.5640, train loss: 0.000201, train metric: 0.007175, vali loss: 0.000175, vali metric: 0.007237
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 72, time(s): 3.5243, train loss: 0.000202, train metric: 0.007156, vali loss: 0.000175, vali metric: 0.007214
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 73, time(s): 3.5319, train loss: 0.000200, train metric: 0.007127, vali loss: 0.000175, vali metric: 0.007249
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 74, time(s): 3.5268, train loss: 0.000199, train metric: 0.007144, vali loss: 0.000175, vali metric: 0.007258
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00017449710139771923
#
# Saving best model for epoch: 75
#
# epoch: 75, time(s): 3.5642, train loss: 0.000198, train metric: 0.007142, vali loss: 0.000174, vali metric: 0.007231
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 76, time(s): 3.5236, train loss: 0.000201, train metric: 0.007128, vali loss: 0.000175, vali metric: 0.007267
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 77, time(s): 3.5307, train loss: 0.000198, train metric: 0.007140, vali loss: 0.000175, vali metric: 0.007218
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 78, time(s): 3.5289, train loss: 0.000198, train metric: 0.007136, vali loss: 0.000175, vali metric: 0.007260
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 79, time(s): 3.5278, train loss: 0.000201, train metric: 0.007149, vali loss: 0.000175, vali metric: 0.007265
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00017438555005355738
#
# Saving best model for epoch: 80
#
# epoch: 80, time(s): 3.5861, train loss: 0.000200, train metric: 0.007167, vali loss: 0.000174, vali metric: 0.007226
# Adjusting learning rate of group 0 to 1.0000e-07.

# %%
# plot metric (MAE) history

plt.figure(figsize=(10, 7))
plt.plot(range(1,len(hist_metric)+1), hist_metric,  color='green', linestyle='-', label='train metric')
plt.plot(range(1,len(hist_vmetric)+1),hist_vmetric, color='blue', linestyle='-', label='validation metric')
plt.xlabel('Epochs')
plt.ylabel('Metric')
plt.legend()
plt.yscale("log")

# %%
# plot loss (MSE) history

plt.figure(figsize=(10, 7))
plt.plot(range(1,len(hist_loss)+1), hist_loss, color='green', linestyle='-', label='train loss')
plt.plot(range(1,len(hist_vloss)+1),hist_vloss, color='blue', linestyle='-', label='validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.yscale("log")

# %%
#test

# load the best model checkpoint
best_model = torch.load('best_model.pth')
best_model_epoch = best_model['epoch']
print(f"Best model was saved at {best_model_epoch} epochs\n")


model = DnCNN()
#model = UNet1D(1,1,32)
#model = DilatedResidualConvNet(1,1)
model.load_state_dict(best_model['model_state_dict'])
model.eval()

#let's do this on cpu (inference is fast)
model.to(torch.device('cpu'))

# test 10 cases
X_test_pt = X_test_pt[:10].type(torch.float).to(torch.device('cpu'))
prediction = model(X_test_pt)
# Out:
# Best model was saved at 80 epochs

# %%
prediction.shape
# Out:
# torch.Size([10, 1, 800])

# %%
#plot results
shift=0
plt.figure(figsize=(20,10))
for i in range(6):
    plt.subplot(2,6,i+1)
    plt.plot(X_test_pt[i+shift].permute(1,0).numpy().reshape(800,), '-b',label="noisy (input)") #input noisy spectrum
    plt.legend()
    plt.subplot(2,6,i+7)
    plt.plot(prediction[i+shift].permute(1,0).detach().numpy().reshape(800,), '-g',label="output") #cleaned spectrum predicted by te model
    plt.plot(Y_test_pt[i+shift].permute(1,0).numpy().reshape(800,), 'or', markersize=1, label = "clean (ground truth)") #ground truth
    plt.legend()
plt.tight_layout()

# %% [markdown]
# **spunti per sperimentare**
#
# *   test model variations: with and w/o BN, try theusing dilated convolutions ([dilation](https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html) parameter), try to analyise in parallel the input with different kernels:
#
#
# ```
# # code snippet example
# self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=20, padding='same', bias=False)
#     self.relu1 = nn.ReLU()
#
# hlayers = []
# for _ in range(num_layers):
#   hlayers.append(nn.Conv1d(in_channels=64, out_channels=64, kernel_size=20, padding='same', bias=False))
#   hlayers.append(nn.ReLU())
#
# self.central_block = nn.Sequential(*hlayers)
#
# self.conv1_b = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=5, padding='same', bias=False)
#     self.relu1_b = nn.ReLU()
#
# hlayers_b = []
# for _ in range(num_layers):
#   hlayers_b.append(nn.Conv1d(in_channels=64, out_channels=64, kernel_size=5, padding='same', bias=False))
#   hlayers_b.append(nn.ReLU())
#
# self.central_block_b = nn.Sequential(*hlayers_b)
#
# self.conv3 = nn.Conv1d(in_channels=64*2, out_channels=1, kernel_size=1, padding='same', bias=False)
#
# def forward(self, x):
#     out = self.relu1(self.conv1(x))
#     out = self.central_block(out)
#
#     out_b = self.relu1_b(self.conv1_b(x))
#     out_b = self.central_block_b(out_b)
#
#     out = torch.cat((out,out_b), dim=1)
#     out = self.conv3(out)
#
#     # residual learning (this way out become the clean spectrum and the network has only to learn the "noise")
#     out = x - out
#     return out
# ```
#
#
#
# *   test medium and high noise cases ...
